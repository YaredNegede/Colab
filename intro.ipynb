# %% [markdown]
# <a href="https://colab.research.google.com/github/YaredNegede/Colab/blob/master/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Edge (Android/iOS) Antispoofing Model Training Setup

# %%
# Clone the PyTorch examples repository (Apache 2.0 Licensed)
# !git clone https://github.com/pytorch/examples.git

import os

# Navigate into the cloned directory
project_dir = 'examples'
if os.path.exists(project_dir):
    # %cd {project_dir}
    print(f"Successfully changed directory to: {os.getcwd()}")
else:
    print(f"Error: Directory '{project_dir}' not found after cloning.")
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 4900, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 4900 (delta 22), reused 19 (delta 19), pack-reused 4867 (from 2)
# Receiving objects: 100% (4900/4900), 41.75 MiB | 20.26 MiB/s, done.
# Resolving deltas: 100% (2420/2420), done.
# /content/examples/examples
# Successfully changed directory to: /content/examples/examples

# %% [markdown]
# numpy

# %%
import torch
import numpy as np

np1 = np.random.rand(2)
print(np1)
# Out:
# [0.85754692 0.47471996]

# %% [markdown]
# torch

# %%
import torch
import numpy as np


torch = torch.rand(1,4,4)
print(torch.dtype)
# Out:
# torch.float32

# %%
import torch
import numpy as np
tensor = torch.zeros(1,2,2)
print(tensor)
# Out:
# tensor([[[0., 0.],
#          [0., 0.]]])
